# %% [markdown]
# # Homework 4

# %% [markdown]
# ### Problem 0

# %%
# %matplotlib inline
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import scipy
from scipy import stats

#this sets the size of the plot to something useful
plt.rcParams["figure.figsize"] = (20,15)
import pandas as pd

# %%
t = np.linspace(0,np.pi*100,np.int(1e5))
N = 10+np.sin(t)
bkgd = stats.norm.rvs(size=np.int(1e5))*np.sqrt(N)+N

# %% [markdown]
# ### Problem 1: Subsets of Data

# %%
# 1 a)
tt = t[0:1000]
x = bkgd[0:1000]
p = plt.scatter(tt,x)

# %%
# 1 b)
start = 500
end = start + 2000
tt2= t[start:end]
xx = bkgd[start:end]
p = plt.scatter(tt2,xx)

# %%
# 1 c)
x2=bkgd[0:len(bkgd)-1: 100]
t2 = t[0: len(t)-1: 100]
p = plt.scatter(t2,x2)

# %% [markdown]
# ### Problem 2: Density

# %%
# 2 a
h = plt.hist2d(t, bkgd, bins=60, density=True)
plt.colorbar()

# %% [markdown]
# 2b) 2D plot above, plots the densities of the points. Meaning, because we have such a large amount of data this allows the points to be grouped into bins.

# %% [markdown]
# ### Problem 3: Folding

# %%
#3 a)
t = np.linspace(0,np.pi*2,np.int(1e5))
N = 10+np.sin(t)
bkgd = stats.norm.rvs(size=np.int(1e5))*np.sqrt(N)+N
p = plt.scatter(t,bkgd)

# %%
# 3b)
h = plt.hist2d(t, bkgd, bins=60, density=True)
plt.colorbar()
